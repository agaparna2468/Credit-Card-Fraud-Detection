# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn as sk
import seaborn as sns

# %%
data = pd.read_csv("creditcard.csv")
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %% [markdown]
# The columns v1, v2, .. v28 are dimensionally reduced features so as to protect sensitive user information. Result of PCA (Principal Component Analysis).
#
# Principal component analysis (PCA) is a popular technique for analyzing large datasets containing a high number of dimensions/features per observation, increasing the interpretability of data while preserving the maximum amount of information, and enabling the visualization of multidimensional data.

# %%
data.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# There are no null values

# %%
data.drop_duplicates(keep = "first", inplace = True)

# %%
data.shape #After dropping duplicates
# Out:
# (283726, 31)

# %% [markdown]
# # EDA
#
# Exploratory data analysis is an approach of analyzing data sets to summarize their main characteristics, often using statistical graphics and other data visualization methods

# %%
data.Class.value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %% [markdown]
# Hence 473 are fraud transactions and 283253 are valid transactions

# %%
valid = data[data.Class == 0]
fraud = data[data['Class'] == 1]

# %%
valid
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
fraud
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(valid.shape)
valid.describe()
# Out:
# (283253, 31)
#                 Time             V1             V2             V3  \
# count  283253.000000  283253.000000  283253.000000  283253.000000
# mean    94835.058093       0.013439      -0.009829       0.012853
# std     47475.550607       1.922179       1.633520       1.457593
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54233.000000      -0.913431      -0.601398      -0.883966
# 50%     84711.000000       0.022562       0.062561       0.182247
# 75%    139308.000000       1.316788       0.797012       1.028261
# max    172792.000000       2.454930      18.902453       9.382558
#
#                   V4             V5             V6             V7  \
# count  283253.000000  283253.000000  283253.000000  283253.000000
# mean       -0.010440       0.006769       0.001251       0.010447
# std         1.398575       1.355816       1.329914       1.177480
# min        -5.683171    -113.743307     -26.160506     -31.764946
# ...

# %%
print(fraud.shape)
fraud.describe()
# Out:
# (473, 31)
#                 Time          V1          V2          V3          V4  \
# count     473.000000  473.000000  473.000000  473.000000  473.000000
# mean    80450.513742   -4.498280    3.405965   -6.729599    4.472591
# std     48636.179973    6.593145    4.122500    6.909647    2.871523
# min       406.000000  -30.552380   -8.402154  -31.103685   -1.313275
# 25%     41203.000000   -5.603690    1.145381   -7.926507    2.288644
# 50%     73408.000000   -2.271755    2.617105   -4.875397    4.100098
# 75%    129095.000000   -0.361428    4.571743   -2.171454    6.290918
# max    170348.000000    2.132386   22.057729    2.250210   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  473.000000  473.000000  473.000000  473.000000  473.000000  ...
# mean    -2.957197   -1.432518   -5.175912    0.953255   -2.522124  ...
# std      5.278831    1.715347    6.858024    5.585950    2.465047  ...
# ...

# %% [markdown]
# From here, we can see the difference in features of Fraud and fair transactions

# %% [markdown]
# # Plots

# %%
sns.countplot(x = data.Class, data = data)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
plt.pie(x = data.Class.value_counts(), labels =['valid', 'fraud'], autopct="%0.2f")
plt.show()

# %% [markdown]
# # Histogram

# %%
cols = data.drop('Class', axis = 'columns')
label = data.Class

# %%
#plot density
#for i,column in enumerate(cols.columns):
    #plt.subplot(1,1, i+1)
#sns.kdeplot(data[data.Class==0],data.V1,color= 'red')
plt.hist(cols['V1'][data.Class==1], histtype=u'step', color= 'green')
    #plt.title(column)
    #plt.show()
#data[data.Class==0][V1].plot(kind='density', label = 'Valid')
#data[data.Class==1][V1].plot(kind='density', label = 'Fraud')
